# %%
import itertools
import cohere
import psycopg2
import os
from dotenv import load_dotenv
from console_app import retrieve_similar, rerank_docs, chatbot_response
import time

# Load environment variables
load_dotenv()
co = cohere.Client(os.getenv("COHERE_API_KEY"))

# DB connection
db_config = {
    'dbname': os.getenv('DB_NAME'),
    'user': os.getenv('DB_USER'),
    'password': os.getenv('DB_PASSWORD'),
    'host': os.getenv('DB_HOST'),
    'port': int(os.getenv('DB_PORT')),
}
conn = psycopg2.connect(**db_config)
cursor = conn.cursor()

# %%
param_grid = {
    "embedding_model": ["small"],
    "top_k": [3, 4, 5, 6],
    "rerank_n": [2, 3, 4, 5],
    "generation_model": ["command-r7b-12-2024", "command-r-08-2024"],
    "max_tokens": [50, 100, 150, 200]
}

# Generate all combinations of parameters with itertools library
search_space = list(itertools.product(
    param_grid["embedding_model"],
    param_grid["top_k"],
    param_grid["rerank_n"],
    param_grid["generation_model"],
    param_grid["max_tokens"]
))

# %%
eval_queries = [
    {"query": "Tell me about supply chain verification projects", "expected": "BlockVerify"},
    {"query": "Any cybersecurity platforms based on AI?", "expected": "CyberDefend, DataFort"},
    {"query": "Who is responsible for the education platform for teacher collaboration?", "expected": "Aiden Ward"},
    {"query": "Which projects are related to AI in Agriculture?", "expected": "GreenFarm Analytics, AgriTechOptimizer, CropGuardian, CropWatcher"},
    {"query": "List all responsible people called Martinez in Construction", "expected": "Daniel Martinez, Jacob Martinez"}
]
# Coherence rate limits: 10 requests per minute for free tier
MAX_CALLS_PER_MIN = 10
results = []

for emb_model, top_k, rerank_n, gen_model, max_tokens in search_space:
    print(f"Testing: emb={emb_model}, top_k={top_k}, rerank_n={rerank_n}, gen={gen_model}, max_tokens={max_tokens}")

    correct = 0
    for case in eval_queries:
        docs = retrieve_similar(case["query"], top_k, emb_model)
        if rerank_n <= top_k:
            reranked = rerank_docs(case["query"], docs, rerank_n)
        answer = chatbot_response(case["query"], reranked, gen_model, max_tokens=max_tokens)

        expected_keywords = [word.strip().lower() for word in case["expected"].split(",")]
        for keyword in expected_keywords:
            if keyword in answer.lower():
                correct += 1
        
        time.sleep(60 / MAX_CALLS_PER_MIN + 0.1)

    results.append(((emb_model, top_k, rerank_n, gen_model, max_tokens), correct))
# Out:
# Testing: emb=small, top_k=3, rerank_n=2, gen=command-r7b-12-2024, max_tokens=50
# Testing: emb=small, top_k=3, rerank_n=2, gen=command-r7b-12-2024, max_tokens=100
# Testing: emb=small, top_k=3, rerank_n=2, gen=command-r7b-12-2024, max_tokens=150
# Testing: emb=small, top_k=3, rerank_n=2, gen=command-r7b-12-2024, max_tokens=200
# Testing: emb=small, top_k=3, rerank_n=2, gen=command-r-08-2024, max_tokens=50
# Testing: emb=small, top_k=3, rerank_n=2, gen=command-r-08-2024, max_tokens=100
# Testing: emb=small, top_k=3, rerank_n=2, gen=command-r-08-2024, max_tokens=150
# Testing: emb=small, top_k=3, rerank_n=2, gen=command-r-08-2024, max_tokens=200
# Testing: emb=small, top_k=3, rerank_n=3, gen=command-r7b-12-2024, max_tokens=50
# Testing: emb=small, top_k=3, rerank_n=3, gen=command-r7b-12-2024, max_tokens=100
# Testing: emb=small, top_k=3, rerank_n=3, gen=command-r7b-12-2024, max_tokens=150
# Testing: emb=small, top_k=3, rerank_n=3, gen=command-r7b-12-2024, max_tokens=200
# Testing: emb=small, top_k=3, rerank_n=3, gen=command-r-08-2024, max_tokens=50
# Testing: emb=small, top_k=3, rerank_n=3, gen=command-r-08-2024, max_tokens=100
# Testing: emb=small, top_k=3, rerank_n=3, gen=command-r-08-2024, max_tokens=150
# Testing: emb=small, top_k=3, rerank_n=3, gen=command-r-08-2024, max_tokens=200
# Testing: emb=small, top_k=3, rerank_n=4, gen=command-r7b-12-2024, max_tokens=50
# Testing: emb=small, top_k=3, rerank_n=4, gen=command-r7b-12-2024, max_tokens=100
# Testing: emb=small, top_k=3, rerank_n=4, gen=command-r7b-12-2024, max_tokens=150
# Testing: emb=small, top_k=3, rerank_n=4, gen=command-r7b-12-2024, max_tokens=200
# Testing: emb=small, top_k=3, rerank_n=4, gen=command-r-08-2024, max_tokens=50
# Testing: emb=small, top_k=3, rerank_n=4, gen=command-r-08-2024, max_tokens=100
# Testing: emb=small, top_k=3, rerank_n=4, gen=command-r-08-2024, max_tokens=150
# Testing: emb=small, top_k=3, rerank_n=4, gen=command-r-08-2024, max_tokens=200
# Testing: emb=small, top_k=3, rerank_n=5, gen=command-r7b-12-2024, max_tokens=50
# Testing: emb=small, top_k=3, rerank_n=5, gen=command-r7b-12-2024, max_tokens=100
# Testing: emb=small, top_k=3, rerank_n=5, gen=command-r7b-12-2024, max_tokens=150
# Testing: emb=small, top_k=3, rerank_n=5, gen=command-r7b-12-2024, max_tokens=200
# Testing: emb=small, top_k=3, rerank_n=5, gen=command-r-08-2024, max_tokens=50
# Testing: emb=small, top_k=3, rerank_n=5, gen=command-r-08-2024, max_tokens=100
# Testing: emb=small, top_k=3, rerank_n=5, gen=command-r-08-2024, max_tokens=150
# Testing: emb=small, top_k=3, rerank_n=5, gen=command-r-08-2024, max_tokens=200
# Testing: emb=small, top_k=4, rerank_n=2, gen=command-r7b-12-2024, max_tokens=50
# Testing: emb=small, top_k=4, rerank_n=2, gen=command-r7b-12-2024, max_tokens=100
# Testing: emb=small, top_k=4, rerank_n=2, gen=command-r7b-12-2024, max_tokens=150
# Testing: emb=small, top_k=4, rerank_n=2, gen=command-r7b-12-2024, max_tokens=200
# Testing: emb=small, top_k=4, rerank_n=2, gen=command-r-08-2024, max_tokens=50
# Testing: emb=small, top_k=4, rerank_n=2, gen=command-r-08-2024, max_tokens=100
# Testing: emb=small, top_k=4, rerank_n=2, gen=command-r-08-2024, max_tokens=150
# Testing: emb=small, top_k=4, rerank_n=2, gen=command-r-08-2024, max_tokens=200
# Testing: emb=small, top_k=4, rerank_n=3, gen=command-r7b-12-2024, max_tokens=50
# Testing: emb=small, top_k=4, rerank_n=3, gen=command-r7b-12-2024, max_tokens=100
# Testing: emb=small, top_k=4, rerank_n=3, gen=command-r7b-12-2024, max_tokens=150
# Testing: emb=small, top_k=4, rerank_n=3, gen=command-r7b-12-2024, max_tokens=200
# Testing: emb=small, top_k=4, rerank_n=3, gen=command-r-08-2024, max_tokens=50
# Testing: emb=small, top_k=4, rerank_n=3, gen=command-r-08-2024, max_tokens=100
# Testing: emb=small, top_k=4, rerank_n=3, gen=command-r-08-2024, max_tokens=150
# Testing: emb=small, top_k=4, rerank_n=3, gen=command-r-08-2024, max_tokens=200
# Testing: emb=small, top_k=4, rerank_n=4, gen=command-r7b-12-2024, max_tokens=50
# Testing: emb=small, top_k=4, rerank_n=4, gen=command-r7b-12-2024, max_tokens=100
# Testing: emb=small, top_k=4, rerank_n=4, gen=command-r7b-12-2024, max_tokens=150
# Testing: emb=small, top_k=4, rerank_n=4, gen=command-r7b-12-2024, max_tokens=200
# Testing: emb=small, top_k=4, rerank_n=4, gen=command-r-08-2024, max_tokens=50
# Testing: emb=small, top_k=4, rerank_n=4, gen=command-r-08-2024, max_tokens=100
# Testing: emb=small, top_k=4, rerank_n=4, gen=command-r-08-2024, max_tokens=150
# Testing: emb=small, top_k=4, rerank_n=4, gen=command-r-08-2024, max_tokens=200
# Testing: emb=small, top_k=4, rerank_n=5, gen=command-r7b-12-2024, max_tokens=50
# Testing: emb=small, top_k=4, rerank_n=5, gen=command-r7b-12-2024, max_tokens=100
# Testing: emb=small, top_k=4, rerank_n=5, gen=command-r7b-12-2024, max_tokens=150
# Testing: emb=small, top_k=4, rerank_n=5, gen=command-r7b-12-2024, max_tokens=200
# Testing: emb=small, top_k=4, rerank_n=5, gen=command-r-08-2024, max_tokens=50
# Testing: emb=small, top_k=4, rerank_n=5, gen=command-r-08-2024, max_tokens=100
# Testing: emb=small, top_k=4, rerank_n=5, gen=command-r-08-2024, max_tokens=150
# Testing: emb=small, top_k=4, rerank_n=5, gen=command-r-08-2024, max_tokens=200
# Testing: emb=small, top_k=5, rerank_n=2, gen=command-r7b-12-2024, max_tokens=50
# Testing: emb=small, top_k=5, rerank_n=2, gen=command-r7b-12-2024, max_tokens=100
# Testing: emb=small, top_k=5, rerank_n=2, gen=command-r7b-12-2024, max_tokens=150
# Testing: emb=small, top_k=5, rerank_n=2, gen=command-r7b-12-2024, max_tokens=200
# Testing: emb=small, top_k=5, rerank_n=2, gen=command-r-08-2024, max_tokens=50
# Testing: emb=small, top_k=5, rerank_n=2, gen=command-r-08-2024, max_tokens=100
# Testing: emb=small, top_k=5, rerank_n=2, gen=command-r-08-2024, max_tokens=150
# Testing: emb=small, top_k=5, rerank_n=2, gen=command-r-08-2024, max_tokens=200
# Testing: emb=small, top_k=5, rerank_n=3, gen=command-r7b-12-2024, max_tokens=50
# Testing: emb=small, top_k=5, rerank_n=3, gen=command-r7b-12-2024, max_tokens=100
# Testing: emb=small, top_k=5, rerank_n=3, gen=command-r7b-12-2024, max_tokens=150
# Testing: emb=small, top_k=5, rerank_n=3, gen=command-r7b-12-2024, max_tokens=200
# Testing: emb=small, top_k=5, rerank_n=3, gen=command-r-08-2024, max_tokens=50
# Testing: emb=small, top_k=5, rerank_n=3, gen=command-r-08-2024, max_tokens=100
# Testing: emb=small, top_k=5, rerank_n=3, gen=command-r-08-2024, max_tokens=150
# Testing: emb=small, top_k=5, rerank_n=3, gen=command-r-08-2024, max_tokens=200
# Testing: emb=small, top_k=5, rerank_n=4, gen=command-r7b-12-2024, max_tokens=50
# Testing: emb=small, top_k=5, rerank_n=4, gen=command-r7b-12-2024, max_tokens=100
# Testing: emb=small, top_k=5, rerank_n=4, gen=command-r7b-12-2024, max_tokens=150
# Testing: emb=small, top_k=5, rerank_n=4, gen=command-r7b-12-2024, max_tokens=200
# Testing: emb=small, top_k=5, rerank_n=4, gen=command-r-08-2024, max_tokens=50
# Testing: emb=small, top_k=5, rerank_n=4, gen=command-r-08-2024, max_tokens=100
# Testing: emb=small, top_k=5, rerank_n=4, gen=command-r-08-2024, max_tokens=150
# Testing: emb=small, top_k=5, rerank_n=4, gen=command-r-08-2024, max_tokens=200
# Testing: emb=small, top_k=5, rerank_n=5, gen=command-r7b-12-2024, max_tokens=50
# Testing: emb=small, top_k=5, rerank_n=5, gen=command-r7b-12-2024, max_tokens=100
# Testing: emb=small, top_k=5, rerank_n=5, gen=command-r7b-12-2024, max_tokens=150
# Testing: emb=small, top_k=5, rerank_n=5, gen=command-r7b-12-2024, max_tokens=200
# Testing: emb=small, top_k=5, rerank_n=5, gen=command-r-08-2024, max_tokens=50
# Testing: emb=small, top_k=5, rerank_n=5, gen=command-r-08-2024, max_tokens=100
# Testing: emb=small, top_k=5, rerank_n=5, gen=command-r-08-2024, max_tokens=150
# Testing: emb=small, top_k=5, rerank_n=5, gen=command-r-08-2024, max_tokens=200
# Testing: emb=small, top_k=6, rerank_n=2, gen=command-r7b-12-2024, max_tokens=50
# Testing: emb=small, top_k=6, rerank_n=2, gen=command-r7b-12-2024, max_tokens=100
# Testing: emb=small, top_k=6, rerank_n=2, gen=command-r7b-12-2024, max_tokens=150
# Testing: emb=small, top_k=6, rerank_n=2, gen=command-r7b-12-2024, max_tokens=200
# Testing: emb=small, top_k=6, rerank_n=2, gen=command-r-08-2024, max_tokens=50
# Testing: emb=small, top_k=6, rerank_n=2, gen=command-r-08-2024, max_tokens=100
# Testing: emb=small, top_k=6, rerank_n=2, gen=command-r-08-2024, max_tokens=150
# Testing: emb=small, top_k=6, rerank_n=2, gen=command-r-08-2024, max_tokens=200
# Testing: emb=small, top_k=6, rerank_n=3, gen=command-r7b-12-2024, max_tokens=50
# Testing: emb=small, top_k=6, rerank_n=3, gen=command-r7b-12-2024, max_tokens=100
# Testing: emb=small, top_k=6, rerank_n=3, gen=command-r7b-12-2024, max_tokens=150
# Testing: emb=small, top_k=6, rerank_n=3, gen=command-r7b-12-2024, max_tokens=200
# Testing: emb=small, top_k=6, rerank_n=3, gen=command-r-08-2024, max_tokens=50
# Testing: emb=small, top_k=6, rerank_n=3, gen=command-r-08-2024, max_tokens=100
# Testing: emb=small, top_k=6, rerank_n=3, gen=command-r-08-2024, max_tokens=150
# Testing: emb=small, top_k=6, rerank_n=3, gen=command-r-08-2024, max_tokens=200
# Testing: emb=small, top_k=6, rerank_n=4, gen=command-r7b-12-2024, max_tokens=50
# Testing: emb=small, top_k=6, rerank_n=4, gen=command-r7b-12-2024, max_tokens=100
# Testing: emb=small, top_k=6, rerank_n=4, gen=command-r7b-12-2024, max_tokens=150
# Testing: emb=small, top_k=6, rerank_n=4, gen=command-r7b-12-2024, max_tokens=200
# Testing: emb=small, top_k=6, rerank_n=4, gen=command-r-08-2024, max_tokens=50
# Testing: emb=small, top_k=6, rerank_n=4, gen=command-r-08-2024, max_tokens=100
# Testing: emb=small, top_k=6, rerank_n=4, gen=command-r-08-2024, max_tokens=150
# Testing: emb=small, top_k=6, rerank_n=4, gen=command-r-08-2024, max_tokens=200
# Testing: emb=small, top_k=6, rerank_n=5, gen=command-r7b-12-2024, max_tokens=50
# Testing: emb=small, top_k=6, rerank_n=5, gen=command-r7b-12-2024, max_tokens=100
# Testing: emb=small, top_k=6, rerank_n=5, gen=command-r7b-12-2024, max_tokens=150
# Testing: emb=small, top_k=6, rerank_n=5, gen=command-r7b-12-2024, max_tokens=200
# Testing: emb=small, top_k=6, rerank_n=5, gen=command-r-08-2024, max_tokens=50
# Testing: emb=small, top_k=6, rerank_n=5, gen=command-r-08-2024, max_tokens=100
# Testing: emb=small, top_k=6, rerank_n=5, gen=command-r-08-2024, max_tokens=150
# Testing: emb=small, top_k=6, rerank_n=5, gen=command-r-08-2024, max_tokens=200

# %%
best = max(results, key=lambda x: x[1])
print("Best Hyperparameters:", best[0])
print("Best Accuracy:", best[1])
# Out:
# Best Hyperparameters: ('small', 4, 4, 'command-r-08-2024', 100)
# Best Accuracy: 10

# %%
# Sort results by accuracy descending
sorted_results = sorted(results, key=lambda x: x[1], reverse=True)

# Print all results ranked
print("\n=== Ranked Grid Search Results ===")
for rank, (params, acc) in enumerate(sorted_results, start=1):
    print(f"{rank}. Accuracy: {acc:.3f} | Params: {params}")

# Get the best
best = sorted_results[0]
print("\nBest Hyperparameters:", best[0])
print("Best Accuracy:", best[1])
# Out:
# === Ranked Grid Search Results ===
# 1. Accuracy: 10.000 | Params: ('small', 4, 4, 'command-r-08-2024', 100)
# 2. Accuracy: 10.000 | Params: ('small', 4, 4, 'command-r-08-2024', 150)
# 3. Accuracy: 10.000 | Params: ('small', 4, 4, 'command-r-08-2024', 200)
# 4. Accuracy: 10.000 | Params: ('small', 5, 4, 'command-r-08-2024', 100)
# 5. Accuracy: 10.000 | Params: ('small', 5, 4, 'command-r-08-2024', 150)
# 6. Accuracy: 10.000 | Params: ('small', 5, 4, 'command-r-08-2024', 200)
# 7. Accuracy: 10.000 | Params: ('small', 5, 5, 'command-r-08-2024', 100)
# 8. Accuracy: 10.000 | Params: ('small', 5, 5, 'command-r-08-2024', 150)
# 9. Accuracy: 10.000 | Params: ('small', 5, 5, 'command-r-08-2024', 200)
# 10. Accuracy: 10.000 | Params: ('small', 6, 4, 'command-r-08-2024', 100)
# 11. Accuracy: 10.000 | Params: ('small', 6, 4, 'command-r-08-2024', 150)
# 12. Accuracy: 10.000 | Params: ('small', 6, 4, 'command-r-08-2024', 200)
# 13. Accuracy: 10.000 | Params: ('small', 6, 5, 'command-r-08-2024', 100)
# 14. Accuracy: 10.000 | Params: ('small', 6, 5, 'command-r-08-2024', 150)
# 15. Accuracy: 10.000 | Params: ('small', 6, 5, 'command-r-08-2024', 200)
# 16. Accuracy: 9.000 | Params: ('small', 6, 5, 'command-r-08-2024', 50)
# 17. Accuracy: 8.000 | Params: ('small', 3, 3, 'command-r7b-12-2024', 50)
# 18. Accuracy: 8.000 | Params: ('small', 3, 3, 'command-r7b-12-2024', 100)
# 19. Accuracy: 8.000 | Params: ('small', 3, 3, 'command-r7b-12-2024', 150)
# 20. Accuracy: 8.000 | Params: ('small', 3, 3, 'command-r7b-12-2024', 200)
# 21. Accuracy: 8.000 | Params: ('small', 3, 3, 'command-r-08-2024', 100)
# 22. Accuracy: 8.000 | Params: ('small', 3, 3, 'command-r-08-2024', 150)
# 23. Accuracy: 8.000 | Params: ('small', 3, 3, 'command-r-08-2024', 200)
# 24. Accuracy: 8.000 | Params: ('small', 4, 3, 'command-r7b-12-2024', 50)
# 25. Accuracy: 8.000 | Params: ('small', 4, 3, 'command-r7b-12-2024', 100)
# 26. Accuracy: 8.000 | Params: ('small', 4, 3, 'command-r7b-12-2024', 150)
# 27. Accuracy: 8.000 | Params: ('small', 4, 3, 'command-r7b-12-2024', 200)
# 28. Accuracy: 8.000 | Params: ('small', 4, 3, 'command-r-08-2024', 100)
# 29. Accuracy: 8.000 | Params: ('small', 4, 3, 'command-r-08-2024', 150)
# 30. Accuracy: 8.000 | Params: ('small', 4, 3, 'command-r-08-2024', 200)
# 31. Accuracy: 8.000 | Params: ('small', 4, 4, 'command-r-08-2024', 50)
# 32. Accuracy: 8.000 | Params: ('small', 5, 3, 'command-r7b-12-2024', 50)
# 33. Accuracy: 8.000 | Params: ('small', 5, 3, 'command-r7b-12-2024', 100)
# 34. Accuracy: 8.000 | Params: ('small', 5, 3, 'command-r7b-12-2024', 150)
# 35. Accuracy: 8.000 | Params: ('small', 5, 3, 'command-r7b-12-2024', 200)
# 36. Accuracy: 8.000 | Params: ('small', 5, 3, 'command-r-08-2024', 100)
# 37. Accuracy: 8.000 | Params: ('small', 5, 3, 'command-r-08-2024', 150)
# 38. Accuracy: 8.000 | Params: ('small', 5, 3, 'command-r-08-2024', 200)
# 39. Accuracy: 8.000 | Params: ('small', 5, 4, 'command-r-08-2024', 50)
# 40. Accuracy: 8.000 | Params: ('small', 5, 5, 'command-r-08-2024', 50)
# 41. Accuracy: 8.000 | Params: ('small', 6, 3, 'command-r7b-12-2024', 100)
# 42. Accuracy: 8.000 | Params: ('small', 6, 3, 'command-r7b-12-2024', 150)
# 43. Accuracy: 8.000 | Params: ('small', 6, 3, 'command-r7b-12-2024', 200)
# 44. Accuracy: 8.000 | Params: ('small', 6, 3, 'command-r-08-2024', 50)
# 45. Accuracy: 8.000 | Params: ('small', 6, 3, 'command-r-08-2024', 100)
# 46. Accuracy: 8.000 | Params: ('small', 6, 3, 'command-r-08-2024', 150)
# 47. Accuracy: 8.000 | Params: ('small', 6, 3, 'command-r-08-2024', 200)
# 48. Accuracy: 8.000 | Params: ('small', 6, 4, 'command-r-08-2024', 50)
# 49. Accuracy: 7.000 | Params: ('small', 3, 2, 'command-r7b-12-2024', 50)
# 50. Accuracy: 7.000 | Params: ('small', 3, 2, 'command-r7b-12-2024', 100)
# 51. Accuracy: 7.000 | Params: ('small', 3, 2, 'command-r7b-12-2024', 150)
# 52. Accuracy: 7.000 | Params: ('small', 3, 2, 'command-r7b-12-2024', 200)
# 53. Accuracy: 7.000 | Params: ('small', 3, 2, 'command-r-08-2024', 50)
# 54. Accuracy: 7.000 | Params: ('small', 3, 2, 'command-r-08-2024', 100)
# 55. Accuracy: 7.000 | Params: ('small', 3, 2, 'command-r-08-2024', 150)
# 56. Accuracy: 7.000 | Params: ('small', 3, 2, 'command-r-08-2024', 200)
# 57. Accuracy: 7.000 | Params: ('small', 3, 3, 'command-r-08-2024', 50)
# 58. Accuracy: 7.000 | Params: ('small', 4, 2, 'command-r7b-12-2024', 50)
# 59. Accuracy: 7.000 | Params: ('small', 4, 2, 'command-r7b-12-2024', 150)
# 60. Accuracy: 7.000 | Params: ('small', 4, 2, 'command-r-08-2024', 50)
# 61. Accuracy: 7.000 | Params: ('small', 4, 2, 'command-r-08-2024', 100)
# 62. Accuracy: 7.000 | Params: ('small', 4, 2, 'command-r-08-2024', 150)
# 63. Accuracy: 7.000 | Params: ('small', 4, 2, 'command-r-08-2024', 200)
# 64. Accuracy: 7.000 | Params: ('small', 4, 3, 'command-r-08-2024', 50)
# 65. Accuracy: 7.000 | Params: ('small', 5, 2, 'command-r7b-12-2024', 100)
# 66. Accuracy: 7.000 | Params: ('small', 5, 2, 'command-r7b-12-2024', 150)
# 67. Accuracy: 7.000 | Params: ('small', 5, 2, 'command-r7b-12-2024', 200)
# 68. Accuracy: 7.000 | Params: ('small', 5, 2, 'command-r-08-2024', 50)
# 69. Accuracy: 7.000 | Params: ('small', 5, 2, 'command-r-08-2024', 100)
# 70. Accuracy: 7.000 | Params: ('small', 5, 2, 'command-r-08-2024', 150)
# 71. Accuracy: 7.000 | Params: ('small', 5, 2, 'command-r-08-2024', 200)
# 72. Accuracy: 7.000 | Params: ('small', 5, 3, 'command-r-08-2024', 50)
# 73. Accuracy: 7.000 | Params: ('small', 6, 2, 'command-r7b-12-2024', 50)
# 74. Accuracy: 7.000 | Params: ('small', 6, 2, 'command-r7b-12-2024', 100)
# 75. Accuracy: 7.000 | Params: ('small', 6, 2, 'command-r7b-12-2024', 150)
# 76. Accuracy: 7.000 | Params: ('small', 6, 2, 'command-r7b-12-2024', 200)
# 77. Accuracy: 7.000 | Params: ('small', 6, 2, 'command-r-08-2024', 50)
# 78. Accuracy: 7.000 | Params: ('small', 6, 2, 'command-r-08-2024', 100)
# 79. Accuracy: 7.000 | Params: ('small', 6, 2, 'command-r-08-2024', 150)
# 80. Accuracy: 7.000 | Params: ('small', 6, 2, 'command-r-08-2024', 200)
# 81. Accuracy: 7.000 | Params: ('small', 6, 3, 'command-r7b-12-2024', 50)
# 82. Accuracy: 6.000 | Params: ('small', 4, 2, 'command-r7b-12-2024', 100)
# 83. Accuracy: 6.000 | Params: ('small', 4, 2, 'command-r7b-12-2024', 200)
# 84. Accuracy: 6.000 | Params: ('small', 4, 4, 'command-r7b-12-2024', 50)
# 85. Accuracy: 6.000 | Params: ('small', 4, 4, 'command-r7b-12-2024', 100)
# 86. Accuracy: 6.000 | Params: ('small', 4, 4, 'command-r7b-12-2024', 150)
# 87. Accuracy: 6.000 | Params: ('small', 4, 4, 'command-r7b-12-2024', 200)
# 88. Accuracy: 6.000 | Params: ('small', 5, 2, 'command-r7b-12-2024', 50)
# 89. Accuracy: 6.000 | Params: ('small', 5, 4, 'command-r7b-12-2024', 50)
# 90. Accuracy: 6.000 | Params: ('small', 5, 4, 'command-r7b-12-2024', 100)
# 91. Accuracy: 6.000 | Params: ('small', 5, 4, 'command-r7b-12-2024', 150)
# 92. Accuracy: 6.000 | Params: ('small', 5, 4, 'command-r7b-12-2024', 200)
# 93. Accuracy: 6.000 | Params: ('small', 5, 5, 'command-r7b-12-2024', 50)
# 94. Accuracy: 6.000 | Params: ('small', 5, 5, 'command-r7b-12-2024', 100)
# 95. Accuracy: 6.000 | Params: ('small', 5, 5, 'command-r7b-12-2024', 150)
# 96. Accuracy: 6.000 | Params: ('small', 5, 5, 'command-r7b-12-2024', 200)
# 97. Accuracy: 6.000 | Params: ('small', 6, 4, 'command-r7b-12-2024', 50)
# 98. Accuracy: 6.000 | Params: ('small', 6, 4, 'command-r7b-12-2024', 100)
# 99. Accuracy: 6.000 | Params: ('small', 6, 4, 'command-r7b-12-2024', 150)
# 100. Accuracy: 6.000 | Params: ('small', 6, 4, 'command-r7b-12-2024', 200)
# 101. Accuracy: 6.000 | Params: ('small', 6, 5, 'command-r7b-12-2024', 100)
# 102. Accuracy: 6.000 | Params: ('small', 6, 5, 'command-r7b-12-2024', 150)
# 103. Accuracy: 5.000 | Params: ('small', 6, 5, 'command-r7b-12-2024', 200)
# 104. Accuracy: 4.000 | Params: ('small', 6, 5, 'command-r7b-12-2024', 50)
# 105. Accuracy: 2.000 | Params: ('small', 4, 5, 'command-r7b-12-2024', 50)
# 106. Accuracy: 2.000 | Params: ('small', 4, 5, 'command-r7b-12-2024', 100)
# 107. Accuracy: 2.000 | Params: ('small', 4, 5, 'command-r7b-12-2024', 150)
# 108. Accuracy: 2.000 | Params: ('small', 4, 5, 'command-r7b-12-2024', 200)
# 109. Accuracy: 2.000 | Params: ('small', 4, 5, 'command-r-08-2024', 50)
# 110. Accuracy: 2.000 | Params: ('small', 4, 5, 'command-r-08-2024', 100)
# 111. Accuracy: 2.000 | Params: ('small', 4, 5, 'command-r-08-2024', 150)
# 112. Accuracy: 2.000 | Params: ('small', 4, 5, 'command-r-08-2024', 200)
# 113. Accuracy: 1.000 | Params: ('small', 3, 4, 'command-r7b-12-2024', 50)
# 114. Accuracy: 1.000 | Params: ('small', 3, 4, 'command-r7b-12-2024', 100)
# 115. Accuracy: 1.000 | Params: ('small', 3, 4, 'command-r7b-12-2024', 150)
# 116. Accuracy: 1.000 | Params: ('small', 3, 4, 'command-r7b-12-2024', 200)
# 117. Accuracy: 1.000 | Params: ('small', 3, 4, 'command-r-08-2024', 50)
# 118. Accuracy: 1.000 | Params: ('small', 3, 4, 'command-r-08-2024', 100)
# 119. Accuracy: 1.000 | Params: ('small', 3, 4, 'command-r-08-2024', 150)
# 120. Accuracy: 1.000 | Params: ('small', 3, 4, 'command-r-08-2024', 200)
# 121. Accuracy: 1.000 | Params: ('small', 3, 5, 'command-r7b-12-2024', 50)
# 122. Accuracy: 1.000 | Params: ('small', 3, 5, 'command-r7b-12-2024', 100)
# 123. Accuracy: 1.000 | Params: ('small', 3, 5, 'command-r7b-12-2024', 150)
# 124. Accuracy: 1.000 | Params: ('small', 3, 5, 'command-r7b-12-2024', 200)
# 125. Accuracy: 1.000 | Params: ('small', 3, 5, 'command-r-08-2024', 50)
# 126. Accuracy: 1.000 | Params: ('small', 3, 5, 'command-r-08-2024', 100)
# 127. Accuracy: 1.000 | Params: ('small', 3, 5, 'command-r-08-2024', 150)
# 128. Accuracy: 1.000 | Params: ('small', 3, 5, 'command-r-08-2024', 200)
#
# Best Hyperparameters: ('small', 4, 4, 'command-r-08-2024', 100)
# Best Accuracy: 10

# %% [markdown]
# Based on these results we see that the top 11 combination from the grid search yield the highest accuracy. Our choice of model parameters will be based on saving ressources, while keeping optimal performance.
#
# Model command-r-08-2024 performs best with 100 tokens and the biggest top_k for the best possible retrieval.

# %% [markdown]
# The chosen model parameters are:
#
# Accuracy: 8.000 | Params: ('small', 5, 4, 'command-r-08-2024', 100)
